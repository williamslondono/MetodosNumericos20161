# %%
#9.13 Resuelva el sistema: x1 + x2 – x3 = –3 6x1 + 2x2 + 2x3 = 2 –3x1 + 4x2 + x3 = 1 por medio de a) eliminación de Gauss simple, 
#b) eliminación de Gauss con pivoteo parcial, y c) método de Gauss-Jordan sin pivoteo parcial.
matrizCoef=[[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]]
sol=[-3.0,2.0,1.0]
x,d,y,i,j,k=[],0.0,0.0,0,0,0
n=len(matrizCoef)

for m in range (len(matrizCoef)):
    x.append(0*len(matrizCoef[0]))
print "a)Gauss simple:\n "

for i in range(0,n):
    for j in range(i,n):
        if(i==j):
            d=matrizCoef[i][j]
            for s in range (0,n):
                matrizCoef[i][s]=((matrizCoef[i][s])/d)
            sol[i]=((sol[i])/d)
        else:
            d=matrizCoef[j][i]
            for s in range (0,n):
                matrizCoef[j][s]=matrizCoef[j][s]-(d*matrizCoef[i][s])
            sol[j]=sol[j]-(d*sol[i])
i=n-1
j=n-1

while(i>=0):
    y=sol[i]
    while(j>=i):
        y=y-x[j]*matrizCoef[i][j]
        j-=1
    x[i]=y
    i-=1
    j=n-1
for i in range (0,n):
    k=i+1
    print "El valor de la incognita X%d es %.2f"%(k,x[i])
    
print ("\nb) Gauss Simple con Pivoteo Parcial:")
m,b,x,n,factor,tol,s,er = [[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]],[-3.0,2.0,1.0],[],3,0.0,0.0,[],0.0
for z in range(0,n):
    x.append(n*0.0)
    s.append(n*0.0)
        
def eliminar(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivotear(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
        
def sustituir(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "    X%d = %.2f"%(k,x[i])
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminar(m,s,n,b,tol,er)
    if (er!=-1):
        sustituir(m,n,b,x)

gauss(m,b,n,x,tol,er)

var,piv,matriz = 0,0,[[1.0,1.0,-1.0,-3.0],[6.0,2.0,2.0,2.0],[-3.0,4.0,1.0,1.0]]

var = len(matriz[0])-1
    
def cambiar(matriz,piv,var):
    temp=0.0
    temp=matriz[piv][piv]
    for y in range(0,var+1):
        matriz[piv][y]=matriz[piv][y]/temp
        
def ceros(matriz,piv,var):
    for x in range(0,var):
        if (x!=piv):
            c = matriz[x][piv]
            for z in range(0,var+1):
                matriz[x][z]=((-1*c)*matriz[piv][z])+matriz[x][z]
                
for a in range(0,var):
    cambiar(matriz,piv,var)
    ceros(matriz,piv,var)
    piv += 1
print ("\nc)Jordan:\n")
for x in range(0,var):
    print "La variable X%d es: %.2f"%(x+1,matriz[x][var])
# Out:
# a)Gauss simple:
#
# El valor de la incognita X1 es -0.25
# El valor de la incognita X2 es -0.50
# El valor de la incognita X3 es 2.25
#
# b) Gauss Simple con Pivoteo Parcial:
#     X1 = -0.25
#     X2 = -0.50
#     X3 = 2.25
#
# c)Jordan:
#
# La variable X1 es: -0.25
# La variable X2 es: -0.50
# La variable X3 es: 2.25
